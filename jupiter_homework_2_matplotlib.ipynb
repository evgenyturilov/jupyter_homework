# %%
# Разминка:
# 1. Вывести график функции y = x**2 + 3x - 1
# 2. Описать названия осей и графика
# 3. Увеличить масштаб фигуры по своему усмотрению
# 4. На этой же фигуре сделать график y = sin(x) * 3
# 5. Сделать график (4) красной прерывистой линией

# 6. Вывести диаграммы количества алмазов:
#    a.) различного состояния
#    b.) различной прозрачности
#          Каждую из диаграмм выведите в интерфейсе subplot в n горизонтально расположенных окошках,
#          где n - количество состояний и видов прозрачности
#    c.) Для алмазов состояния Ideal вывести график зависимости массы камня (в каратах) от цены
#        (будет более целесообразно сделать график из точек, т.е. с дискретными значениями).
# 7. Есть ли основания полагать, что для данного состояния характерна прямая зависимость цены от массы кристалла?

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
import numpy as np

# %%
diamonds = pd.read_csv("/home/pi/Desktop/GB_Dev/PY/Jupiter_homework/jupyter_notebook/diamonds.csv")

# %%
fig = plt.figure(figsize=(10,6))

# %%
ax = fig.add_axes([0, 0, 1, 1])

# %%
x = np.linspace(-10,10,21)
y = x**2
plt.grid()
plt.title('square')
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y)

# %%
plt.show()

# %%
diamonds
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
plt.plot(diamonds['carat'], diamonds['price'])
